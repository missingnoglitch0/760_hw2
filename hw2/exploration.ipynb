# %%
import pandas as pd
import seaborn as sns

# %%
### 2.6 
colnames = ['x0', 'x1', 'y']
df_1 = pd.read_csv('./Homework 2 data/D1.txt', sep=' ', names=colnames, header=None, index_col=False)
df_2 = pd.read_csv('./Homework 2 data/D2.txt', sep=' ', names=colnames, header=None, index_col=False)
sns.relplot(data=df_1, x='x0', y='x1', hue='y').add_legend()
sns.relplot(data=df_2, x='x0', y='x1', hue='y').add_legend()
# df
# Out:
# /home/digesmartin/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/digesmartin/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/digesmartin/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
colnames = ['x0', 'x1', 'y']
df = pd.read_csv('./Homework 2 data/D1.txt', sep=' ', names=colnames, header=None, index_col=False)
# df

# %%
df_fail_1 = df[df['x1'] < 0.363539]
df_fail_1
# Out:
#            x0        x1  y
# 0    0.264185  0.178456  0
# 1    0.409499  0.213456  1
# 3    0.573685  0.282145  1
# 11   0.051930  0.224059  1
# 13   0.218459  0.094800  0
# ..        ...       ... ..
# 986  0.195872  0.122877  0
# 990  0.924543  0.076672  0
# 991  0.197509  0.086896  0
# 996  0.625005  0.233578  1
# 999  0.142654  0.226182  1
#
# [352 rows x 3 columns]

# %%
succeed_2 = df_fail_1[df_fail_1['x0'] >= 0.254088]
fail_2 = df_fail_1[df_fail_1['x0'] < 0.254088]
fail_2_num = len(fail_2)
succeed_2_num = len(succeed_2)
succeed_2_1 = sum(succeed_2['y'] == 1)
print(succeed_2_num, succeed_2_1)

fail_2_1 = sum(fail_2['y'] == 1)
print(fail_2_num, fail_2_1)
# Out:
# 272 142
# 80 35

# %%
colnames = ['x0', 'x1', 'y']
df = pd.read_csv('handcrafted_dataset.txt', sep=' ', names=colnames, header=None, index_col=False)
df
# Out:
#    x0  x1  y
# 0   1   1  1
# 1   1   2  0
# 2   2   2  1
# 3   2   1  0

# %%
df
sns.relplot(data=df, x='x1', y='x2', hue='y').add_legend()
# Out:
# /home/digesmartin/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/digesmartin/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/digesmartin/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
